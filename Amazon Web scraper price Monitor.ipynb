# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime

# %%
url="https://www.amazon.in/LEOTUDE-Oversized-Sleeve-Cottonblend-FS49_Purple_CHILL_P_Purple_M/dp/B0GD655D11/ref=sr_1_4_sspa?crid=35FXCEZRAG4LT&dib=eyJ2IjoiMSJ9.ST6B37338hPsqoohsa_RqZxSrV9z-CbaYwotiK1GYGu-XY9GfFbMgr0ZFrEVbYXlZKOw9F9zYYicOo6w3CByTxq16lLm-l6oVzRIQJ2XG5UiLbdZ7zSwiQUYD2bpxYNJBmGgJyMjx_KwH2tC_u23cRGNoPUEwZJ0AMsta-xfhuA8MD8kPJAFvpu1g6tT4Kj5Q2CmTF9Hn01lIiWEXUMdEHTtuQTHVZt3tpGSaBi4V8sSvqguEAnfLWMlXh56idALCJ4d_uUefka5pxPFYdg3vkQN2qL9j_nQRveE__PLxA0.R9jVxLf2kvlQi4yHJev7HCWYluAy6UykqbxGnLj6egQ&dib_tag=se&keywords=t%2B-shirts&qid=1783481642&sprefix=%2Caps%2C293&sr=8-4-spons&aref=zfa2e3sLHD&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1"
headers = {
   "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36 Edg/149.0.0.0"
}
response = requests.get(url,headers=headers)
soup1= BeautifulSoup(response.content,'html.parser')
soup2=BeautifulSoup(soup1.prettify(),'html.parser')
title=soup2.find(id='title').get_text().strip()
price=soup2.find(class_='a-price-whole').get_text().strip()
print(title)
print(price)
# Out:
# LEOTUDE Men's Oversized Drop Shoulder Cool and Stylish Half Sleeve Round Neck Baggy Fit Latest Graphic Printed Design Combo T-Shirt for Man's (Color_Purple)
# 265

# %%
import datetime
today=datetime.date.today()
print(today)
# Out:
# 2026-07-08

# %%
header=['title','price','date']
data=[title,price,today]
type(data)
# Out:
# list

# %%
import csv

with open('AmazonWebScrapingDatasets.csv','w',newline='',encoding='UTF8')as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

# %%
def check_price():
    url="https://www.amazon.in/LEOTUDE-Oversized-Sleeve-Cottonblend-FS49_Purple_CHILL_P_Purple_M/dp/B0GD655D11/ref=sr_1_4_sspa?crid=35FXCEZRAG4LT&dib=eyJ2IjoiMSJ9.ST6B37338hPsqoohsa_RqZxSrV9z-CbaYwotiK1GYGu-XY9GfFbMgr0ZFrEVbYXlZKOw9F9zYYicOo6w3CByTxq16lLm-l6oVzRIQJ2XG5UiLbdZ7zSwiQUYD2bpxYNJBmGgJyMjx_KwH2tC_u23cRGNoPUEwZJ0AMsta-xfhuA8MD8kPJAFvpu1g6tT4Kj5Q2CmTF9Hn01lIiWEXUMdEHTtuQTHVZt3tpGSaBi4V8sSvqguEAnfLWMlXh56idALCJ4d_uUefka5pxPFYdg3vkQN2qL9j_nQRveE__PLxA0.R9jVxLf2kvlQi4yHJev7HCWYluAy6UykqbxGnLj6egQ&dib_tag=se&keywords=t%2B-shirts&qid=1783481642&sprefix=%2Caps%2C293&sr=8-4-spons&aref=zfa2e3sLHD&sp_csd=d2lkZ2V0TmFtZT1zcF9hdGY&th=1&psc=1"
    headers = {
       "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/149.0.0.0 Safari/537.36 Edg/149.0.0.0"
    }
    response = requests.get(url,headers=headers)
    soup1= BeautifulSoup(response.content,'html.parser')
    soup2=BeautifulSoup(soup1.prettify(),'html.parser')
    title=soup2.find(id='title').get_text().strip()
    price=soup2.find(class_='a-price-whole').get_text().strip()
    import datetime
    today=datetime.date.today()
    import csv
    header=['title','price','date']
    data=[title,price,today]
    with open('AmazonWebScrapingDatasets.csv','a+',newline='',encoding='UTF8')as f:
        writer=csv.writer(f)
        writer.writerow(data)

# %%
import time

while True:
    check_price()
    print("Checked at:", datetime.datetime.now())
    time.sleep(86400)
# Out:
# Checked at: 2026-07-08 12:19:22.466393

# %%
df=pd.read_csv(r"AmazonWebScrapingDatasets.csv")
df
# Out:
#                                                title  price        date
# 0  LEOTUDE Men's Oversized Drop Shoulder Cool and...    265  2026-07-08
# 1  LEOTUDE Men's Oversized Drop Shoulder Cool and...    265  2026-07-08

# %%
import os

print(os.path.exists("AmazonWebScrapingDatasets.csv"))
# Out:
# True
